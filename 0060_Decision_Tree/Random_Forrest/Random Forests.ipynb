# %%
import pandas as pd

df = pd.read_csv("./classification.csv")

df.head()
# Out:
#          age   interest  success
# 0  23.657801  18.859917      0.0
# 1  22.573729  17.969223      0.0
# 2  32.553424  29.463651      0.0
# 3   6.718035  25.704665      1.0
# 4  14.401919  16.770856      0.0

# %%
from sklearn.model_selection import train_test_split

X = df[["age", "interest"]].values
y = df["success"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

import numpy as np

scores = cross_val_score(RandomForestClassifier(criterion = "entropy", n_estimators = 10), X, y, cv = KFold(n_splits = 10))

print(scores)
print(np.mean(scores))
# Out:
# [0.93333333 0.96666667 1.         0.9        0.83333333 0.9
#  0.96666667 0.93103448 0.96551724 0.96551724]
# 0.9362068965517241

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(criterion = "entropy", n_estimators = 30)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))

# %%
# Hinweis: Damit dieser Befehl funktioniert, muss die 
# "helper.py" - Datei im selben Ordner liegen, wie das
# aktuelle Jupyter Notebook

from helper import plot_classifier

# Trainings-Daten plotten
plot_classifier(model, X_train, y_train, proba = False, xlabel = "Alter", ylabel = "Interesse")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c91cdb4b7f55> in <module>
#       6
#       7 # Trainings-Daten plotten
# ----> 8 plot_classifier(model, X_train, y_train, proba = False, xlabel = "Alter", ylabel = "Interesse")
#
# NameError: name 'model' is not defined

# %%
# Testdaten plotten
plot_classifier(model, X_test, y_test, proba = False, xlabel = "Alter", ylabel = "Interesse")

# %%
plot_classifier(model, X_test, y_test, proba = True, xlabel = "Alter", ylabel = "Interesse")
